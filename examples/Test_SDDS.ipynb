# %%
from pathlib import Path
import os
import sys

current_location = Path(os.getcwd())
parent_directory = current_location.parent

sys.path.append(str(parent_directory))

# %%
import data_platform.datasource as ds
from data_platform.config import ConfigManager
from data_platform.datasource.science_direct import ScienceDirectDS, ScienceDirectFactory

# %%
current_path = Path(os.getcwd())
data_path = current_path / 'data'
xml_path = data_path / 'unprocessed_articles_xml'

# %% [markdown]
# ## 构造配置文件

# %%
config = ConfigManager({
    "init": {
        "location": xml_path    
    }
})

# %% [markdown]
# ## 解析xml文件夹或文件

# %%
ds = ScienceDirectDS(config)
# Out:
# Parsing file 10.xml error:  There is no article.
# Parsing file 109.xml error:  There is no article.
# Parsing file 111.xml error:  There is no article.
# Parsing file 116.xml error:  There is no article.
# Parsing file 117.xml error:  There is no body.
# Parsing file 119.xml error:  There is no body.
# Parsing file 12.xml error:  There is no article.
# Parsing file 122.xml error:  There is no article.
# Parsing file 125.xml error:  There is no article.
# Parsing file 126.xml error:  There is no article.
# Parsing file 129.xml error:  There is no article.
# Parsing file 136.xml error:  There is no article.
# Parsing file 140.xml error:  There is no article.
# Parsing file 142.xml error:  There is no body.
# Parsing file 145.xml error:  There is no article.
# Parsing file 146.xml error:  There is no article.
# Parsing file 150.xml error:  There is no article.
# Parsing file 158.xml error:  There is no body.
# Parsing file 160.xml error:  There is no tail.
# Parsing file 161.xml error:  There is no article.
# Parsing file 162.xml error:  There is no article.
# Parsing file 163.xml error:  There is no body.
# Parsing file 164.xml error:  There is no article.
# Parsing file 168.xml error:  There is no article.
# Parsing file 169.xml error:  There is no article.
# Parsing file 17.xml error:  There is no body.
# Parsing file 172.xml error:  There is no article.
# Parsing file 173.xml error:  There is no body.
# Parsing file 175.xml error:  There is no article.
# Parsing file 176.xml error:  There is no body.
# Parsing file 180.xml error:  There is no article.
# Parsing file 181.xml error:  There is no body.
# Parsing file 191.xml error:  There is no article.
# Parsing file 192.xml error:  There is no article.
# Parsing file 193.xml error:  There is no article.
# Parsing file 194.xml error:  There is no article.
# Parsing file 195.xml error:  There is no article.
# Parsing file 199.xml error:  There is no article.
# Parsing file 2.xml error:  There is no body.
# Parsing file 20.xml error:  There is no body.
# Parsing file 200.xml error:  There is no article.
# Parsing file 21.xml error:  There is no article.
# Parsing file 28.xml error:  There is no article.
# Parsing file 3.xml error:  There is no body.
# Parsing file 30.xml error:  There is no article.
# Parsing file 31.xml error:  There is no body.
# Parsing file 4.xml error:  There is no article.
# Parsing file 47.xml error:  There is no article.
# Parsing file 50.xml error:  There is no body.
# Parsing file 51.xml error:  There is no article.
# Parsing file 54.xml error:  There is no body.
# Parsing file 59.xml error:  There is no body.
# Parsing file 60.xml error:  There is no article.
# Parsing file 62.xml error:  There is no body.
# Parsing file 80.xml error:  There is no body.
# Parsing file 81.xml error:  There is no tail.
# Parsing file 83.xml error:  There is no body.
# Parsing file 95.xml error:  There is no body.
# Parsing file 96.xml error:  There is no tail.

# %%
doc_dict = ds.read_doc()

# %%
len(doc_dict)
# Out:
# 141

# %%
next(iter(doc_dict.items()))
# Out:
# (DocKeyPair(docset_name='_default', doc_name='97'),
#  {'root': {'section_list': [{'subsections': [],
#      'paragraphs': [{'inline_list': [{'type': 'text',
#          'content': 'Introduction',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'st020'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'Attention allocation, updating working memory, and language processing are interdependent cognitive tasks related to the focused direction of limited resources, refreshing and substituting information in the current focus of attention, and receiving/sending verbal communication, respectively. These systems are probably impossible to study in isolation, which makes interpretation of findings related to any one of them challenging. For example, we know that children with an unexpected and disproportionate impairment in language development known as specific language impairment (SLI) show deficits relative to age-matched peers on measures of attention (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Finneran, Francis, & Leonard, 2009',
#          'tag_attr': {'refid': ['b0120'], 'id': 'c0025'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') and working memory (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Archibald & Gathercole, 2007',
#          'tag_attr': {'refid': ['b0030'], 'id': 'c0030'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Despite efforts to employ nonlinguistic tasks in these studies, the interdependency of the cognitive systems supporting working memory, attention, and language processing makes it difficult to rule out entirely explanations related to the language deficit in SLI. Another concern arising from these studies relates to the potential discrepancy in the cognitive load imposed by the tasks on children with and without impairments. Even in cases where children with impairments perform accurately, the cognitive load of the task may be higher, requiring the recruitment of additional or alternate resources. The current study provided a systematic examination of the relationship among working memory skills, language abilities, and cognitive functioning by examining whether performance on a selective attention task imposing varying but individually adjusted memory demands is dependent on working memory and/or language abilities in children with and without impairments.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0025', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'Attention is viewed as a limited capacity system (e.g.,',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Kahneman, 1973; Lavie, 2005; Lavie, Hirst, de Fockert, & Viding, 2004',
#          'tag_attr': {'refid': ['b0165', 'b0200', 'b0205'], 'id': 'r0005'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') that consists of multiple components, including the ability to focus, sustain, and switch mental focus (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Parasuraman & Davies, 1984; Posner, 1978; Shiffrin, 1988',
#          'tag_attr': {'refid': ['b0245', 'b0250', 'b0295'], 'id': 'r0010'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Essentially, in functional terms, attention refers to the ability to selectively process information, a critical aspect of our cognitive capacities (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Fougnie, 2008',
#          'tag_attr': {'refid': ['b0130'], 'id': 'c0035'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Attentional functions performed by distinct networks include alerting to achieve a general state of responsiveness to sensory stimulation, orienting to a subset of sensory information for privileged processing, and executive attention acting on post-sensory representations when competition exists for access to a central, limited-capacity system (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Fan, McCandliss, Sommer, Raz, & Posner, 2002; Posner & Petersen, 1990',
#          'tag_attr': {'refid': ['b0115', 'b0255'], 'id': 'r0015'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Executive attention is considered a domain-general resource shared broadly in post-perceptual cognitive tasks such as those under study in the current work.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0030', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'Another critical aspect of our cognitive capacities is working memory, the ability to retain task-relevant information in a highly activated and accessible state over time (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Hambrick, Kane, & Engle, 2005; Kane & Engle, 2002',
#          'tag_attr': {'refid': ['b0155', 'b0175'], 'id': 'r0020'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). One key component of working memory is a controlled attentional resource responsible for the coordination of storage and processing within working memory (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Bayliss, Jarrold, Gunn, & Baddeley, 2003; Engle, Tuholski, Laughlin, & Conway, 1999; Kane et al., 2004',
#          'tag_attr': {'refid': ['b0065', 'b0110', 'b0180'], 'id': 'r0025'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). There is clearly a role for the executive attentional resource described above in the notion of a controlled attentional resource or “central executive” (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Baddeley & Hitch, 1974',
#          'tag_attr': {'refid': ['b0050'], 'id': 'c0040'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') in working memory. Indeed, many studies have demonstrated the close relationship between attention and working memory (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Bleckley, Durso, Crutchfield, Engle, & Khanna, 2003; Martinussen, Hayden, Hogg-Johnson, & Tannock, 2005; Vogel, McCollough, & Machizawa, 2005',
#          'tag_attr': {'refid': ['b0075', 'b0220', 'b0320'], 'id': 'r0030'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text', 'content': ').', 'init_args': (), 'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0035', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'Nevertheless, the constructs of executive attention and the central executive of working memory are not entirely isomorphic. The central executive of working memory is a broader concept incorporating responsibility for the monitoring of ongoing cognitive processes and actions, the selective activation of relevant representations and procedures, and the suppression of irrelevant, distracting ones (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Oberauer, Süβ, Wilhelm, & Wittman, 2003',
#          'tag_attr': {'refid': ['b0240'], 'id': 'c0045'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Beyond the theoretical distinctions, however, it is challenging to empirically demonstrate the unique contributions of executive attention and central executive/working memory processes. In one study of healthy adults, the best model of the data included both attention and working memory as separate predictors of intelligence (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Schweizer & Moosbrugger, 2004',
#          'tag_attr': {'refid': ['b0285'], 'id': 'c0050'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). In the current study, we further examined the relationship between attention and working memory by having participants complete a selective attention task under different working memory loads while individually equating the demands of another component of working memory, short-term storage.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0040', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'The operation of the central executive of working memory on relevant stimuli necessitates the retention of those stimuli in an accessible state. These basic memory abilities are the second main component of working memory and are conceived of as short-term memory stores (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Baddeley & Hitch, 1974',
#          'tag_attr': {'refid': ['b0050'], 'id': 'c0055'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') or a functional store composed of an activated subset of information held in long-term memory (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Cowan, 1999',
#          'tag_attr': {'refid': ['b0100'], 'id': 'c0060'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). It is generally agreed that there is some domain specificity in the short-term storage of information. According to one of the most prominent working memory models (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Baddeley, 1986; Baddeley & Hitch, 1974',
#          'tag_attr': {'refid': ['b0040', 'b0050'], 'id': 'r0035'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '), distinct phonological and visuospatial short-term memory stores support retention. Other models account for domain specificity in working memory by allowing for interference between similar representations (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Cowan, 1999',
#          'tag_attr': {'refid': ['b0100'], 'id': 'c0065'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') and the influence of domain-specific cognitive operations such as verbal rehearsal and chunking of spatial patterns (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Oberauer et al., 2003',
#          'tag_attr': {'refid': ['b0240'], 'id': 'c0070'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text', 'content': ').', 'init_args': (), 'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0045', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'There is now considerable evidence that working memory involves some resource sharing; that is, there is some trade-off between the storage and processing demands of working memory tasks (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Barrouillet, Bernardin, & Camos, 2004',
#          'tag_attr': {'refid': ['b0055'], 'id': 'c0075'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). According to these accounts, controlled attentional resources shift from the processing demands of the task to the refreshing or rehearsal of the material in storage (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Barrouillet et al., 2004; Case, Kurland, & Goldberg, 1982; Towse & Hitch, 1995',
#          'tag_attr': {'refid': ['b0055', 'b0090', 'b0300'], 'id': 'r0040'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). It follows from this that individual differences, both in the capacity for storage and in controlled attention, constrain performance. To focus on the controlled attentional resource in working memory in the current study, we employed a novel approach involving equating storage demands across individuals.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0050', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'Language processing is a broad term encompassing the complex computational knowledge base required to send and receive verbal messages using phonological, mophosyntactic, semantic, and other conventions. Language learning places high demands on domain-general information processing abilities; language stimuli must be quickly encoded and retained, placing a load on the speed or capacity of online processing resources. Consistent with this view, current language processing theories incorporate domain-general mechanisms. For example, recent language acquisition theories include a domain-general statistical or probabilistic learning mechanism (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Saffran, 2003',
#          'tag_attr': {'refid': ['b0275'], 'id': 'c0080'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). As well, all sentence parsing models include a limited-capacity memory constraint characteristic of general cognition (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Kelly & Martin, 1994',
#          'tag_attr': {'refid': ['b0185'], 'id': 'c0085'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text', 'content': ').', 'init_args': (), 'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0055', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'It has been suggested that working memory supports language learning (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Baddeley, 2003',
#          'tag_attr': {'refid': ['b0045'], 'id': 'c0090'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Ample evidence links working memory to language comprehension and expression in first language learners (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Gilchrist, Cowan, & Naveh-Benjamin, 2008; King & Just, 1991',
#          'tag_attr': {'refid': ['b0145', 'b0190'], 'id': 'r0045'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') and second language learners (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Andersson, 2010; Martin & Ellis, 2012',
#          'tag_attr': {'refid': ['b0020', 'b0215'], 'id': 'r0050'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Findings of a relationship between language performance and verbal working memory measures, however, do not clearly demonstrate a role of working memory in supporting language learning. Indeed, researchers have argued that all of these tasks tap a single language processing resource (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Caplan & Waters, 1999; MacDonald & Christiansen, 2002',
#          'tag_attr': {'refid': ['b0085', 'b0210'], 'id': 'r0055'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Evidence of a relationship between language abilities and a domain-general working memory component would be strengthened by findings of links between language performance and nonlinguistic working memory tasks, as investigated in the current study. It is important to remember the multiple components of working memory here and that the short-term storage component is considered domain specific. Many studies have demonstrated strong links between measures of phonological processing and language abilities (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Coady, 2013; Gathercole, 2006; Vandewalle, Boets, Ghesquière, & Zink, 2012',
#          'tag_attr': {'refid': ['b0095', 'b0140', 'b0310'], 'id': 'r0060'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). It follows from this that individual differences in domain-specific storage capacity could account for the previously established links between language and working memory. To focus on the relationship between language performance and domain-general central executive or executive attention processes, storage demands must be equated across participants as in the current study.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0060', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'One additional line of evidence for the relationship among attention, working memory, and language processing comes from children with impairments. Children with SLI have a disproportionate impairment in language learning. Nevertheless, nonlinguistic deficits in children who meet criteria for SLI are commonly reported (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Gallinat & Spaulding, 2012',
#          'tag_attr': {'refid': ['b0135'], 'id': 'c0095'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Indeed, lower performance by SLI groups relative to age-matched typically developing groups has been found for measures of attention (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Finneran et al., 2009',
#          'tag_attr': {'refid': ['b0120'], 'id': 'c0100'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '), working memory (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Archibald & Gathercole, 2007',
#          'tag_attr': {'refid': ['b0030'], 'id': 'c0105'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '), and processing speed (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Miller, Kail, Leonard, & Tomblin, 2001',
#          'tag_attr': {'refid': ['b0225'], 'id': 'c0110'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Such findings have led to the suggestion that a domain-general impairment in information processing speed (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Kail, 1994',
#          'tag_attr': {'refid': ['b0170'], 'id': 'c0115'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') or capacity (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Bishop, 1992',
#          'tag_attr': {'refid': ['b0070'], 'id': 'c0120'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') underlies SLI. Once again, however, examining the relationships between language and cognitive functioning is challenged by the overlap in task demands often tapping each of these systems. In one of the first studies to systematically differentiate children with language impairments with or without working memory impairments,',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Noonan, Redmond, and Archibald (2014)',
#          'tag_attr': {'refid': ['b0235'], 'id': 'c0125'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ' demonstrated unique impacts on grammaticality judgment of these separable impairments. The findings are important because they highlight the interdependency of the systems but provide evidence against a causal connection between a working memory impairment and SLI. Consistent with this notion, poorer scores have been found for children with attention deficit disorders relative to age-matched peers on measures of language even though many of these children do not meet criteria for SLI (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Redmond, 2005; Redmond, Thompson, & Goldstein, 2011',
#          'tag_attr': {'refid': ['b0265', 'b0270'], 'id': 'r0065'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text', 'content': ').', 'init_args': (), 'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0065', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'The aim of the current study was to systematically examine the relationship among executive attention, working memory executive skills, and language abilities with short-term memory demands individually adjusted across participants. To do this, we adapted a procedure employed by Cowan and colleagues (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Cowan, Morey, AuBuchon, Zwilling, & Gilchrist, 2010',
#          'tag_attr': {'refid': ['b0105'], 'id': 'c0130'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') to investigate whether executive attention or storage capacity accounted for the developmental increase in working memory across three groups: young children aged 6 or 7',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'hsp',
#          'tag_text': '',
#          'tag_attr': {'sp': '0.25'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': 'years, older children aged 12 or 13',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'hsp',
#          'tag_text': '',
#          'tag_attr': {'sp': '0.25'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': 'years, and adults. In Cowan and colleagues’ study, an array of different colored items was presented, including either one shape (i.e., all circles) or two shapes (i.e., circles and triangles), followed by an array including a single shape. Participants were instructed to attend to one shape only (e.g., the circles) and to decide whether the shape in the second array was identical to the one that had been in the same location in the previous array. Attention was manipulated by including one shape (all target shapes) or two shapes (target plus distractor shapes) such that if distractor shapes could be ignored, fewer items would need to be retained in memory. Working memory load was manipulated by varying the number of total shapes in the array. A disproportionate attention-related effect was found for the young group relative to both the older child and adult groups under conditions of high working memory load (six items in an array) but not low working memory load (four items). The results were suggested to indicate that a fundamental storage capacity difference accounts for the developmental increase in working memory capacity and that attentional control was present in young children provided that working memory load was minimized. These findings further underscore the need to adjust storage demands based on individual short-term memory capacity as in the current study.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0070', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'In the current study, school-age children completed a selective attention task under individually determined high or low working memory load conditions following',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Cowan and colleagues (2010)',
#          'tag_attr': {'refid': ['b0105'], 'id': 'c0135'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ' as well as measures of working memory capacity and language abilities. The first goal was to examine the interaction between selective attention and working memory load. A cost of the attention manipulation was expected in the high working memory condition but not in the low working memory condition. The reasoning was that the cost of additional attentional control would not exceed working memory capacity in the low load condition, resulting in no performance decrement, whereas the cost would exceed working memory capacity in the high load condition, impairing recall accuracy. A second aim was to evaluate whether general working memory capacity or language ability measures were related to the processing time or accuracy of responses. We expected an interaction between measures of working memory capacity and performance on our selective attention task. An attention-related advantage was expected for individuals with high working memory capacity over those with low working memory capacity given their greater available resources. No predictive hypothesis was established regarding language abilities. The role of a domain-general mechanism related to attention or working memory in language learning would be supported by results indicating a relationship between our measures of language abilities and our nonlinguistic selective attention/working memory task.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0075', 'view': 'all'}}],
#      'init_args': (),
#      'init_kwargs': {'section_title': 'Introduction',
#       'role': 'introduction',
#       'id': 's0005',
#       'view': 'all'}},
#     {'subsections': [],
#      'paragraphs': [{'inline_list': [{'type': 'text',
#          'content': 'Method',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'st025'}}],
#      'init_args': (),
#      'init_kwargs': {'section_title': 'Method', 'id': 's0010', 'view': 'all'}},
#     {'subsections': [],
#      'paragraphs': [{'inline_list': [{'type': 'text',
#          'content': 'Results',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'st055'}}],
#      'init_args': (),
#      'init_kwargs': {'section_title': 'Results',
#       'id': 's0040',
#       'view': 'all'}},
#     {'subsections': [],
#      'paragraphs': [{'inline_list': [{'type': 'text',
#          'content': 'Discussion',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'st080'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'The current study systematically examined the relationships among selective attention, working memory, and language abilities in school-age children. Performance accuracy differences were evident when selective attention was required, resulting in a cost under conditions of high working memory load but not low working memory load. As well, general working memory but not language abilities were positively related to overall accuracy on the experimental selective attention task regardless of the load, selective attention requirements, or span length at which the task was completed. Differences in response times based on task load and selective attention requirements were influenced by an individual’s storage capacity. For those with short spans, response time was faster under low load conditions and faster when 2 shapes were present. Those with long spans, however, were relatively impervious to the load and attention manipulation, showing no systematic difference in response time when working above or within span or when viewing 1 or 2 shapes. Language abilities but not general working memory skills were related to response times on the task in somewhat complex ways. Generally speaking, those with lower language scores completed the task more slowly, a difference that was particularly marked for those with long spans.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0185', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'First, consider the results related to demands for selective attention. When the total number of items presented was within the individual’s storage capacity such that the working memory load imposed was low, the requirements for selective attention had no significant impact on performance accuracy. Conversely, when the total number of items presented exceeded the individual’s storage capacity such that the working memory load imposed was high, there was a selective attention cost, resulting in less accurate performance. The interpretation here is quite clear. When working below span, sufficient resources were available to do the task regardless of whether distractor shapes were present or not. When working above span, however, sufficient resources were not available, resulting in impaired filtering. As a result, irrelevant items could not be filtered out, leading participants to attempt to retain both target and distractor shapes. Notice that the argument is not simply that efforts to filter were abandoned, which would render the 1 shape–above span and 2 shapes–above span conditions equal in terms of the total number of items to be retained. Rather, the reduced accuracy in the above span–2 shapes condition indicates an attention-related cost. The effort of trying to filter out irrelevant items in conjunction with insufficient memory resources resulted in impaired attentional control.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0190', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'These findings are consistent with those reported by',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Cowan and colleagues (2010)',
#          'tag_attr': {'refid': ['b0105'], 'id': 'c0265'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ' using a similar paradigm. In their study, no group differences between their young children (6 or 7',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'hsp',
#          'tag_text': '',
#          'tag_attr': {'sp': '0.25'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': 'years), older children (11 or 12',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'hsp',
#          'tag_text': '',
#          'tag_attr': {'sp': '0.25'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': 'years), and adults were observed when completing their selective attention task on small arrays (4 items), whereas significantly lower scores were found for the young group only on larger arrays (6 items). As with our findings, filtering was impaired when working above span for the youngest group in Cowan and colleagues’ study and more generally in our study. It could be argued that the lack of an attention-related cost in the older groups in Cowan and colleagues’ study was due to the design not including above span arrays for these groups. The maximum array administered by Cowan and colleagues had 6 items, which was lower than the average span of the children in the current study. It might also be the case that the individually adjusted span lengths corresponding to high and low working memory load in the current study more clearly revealed the costs of selective attention demands when working above span. Our findings provide clear evidence of an interaction between executive attention and working memory load such that attentional costs occur only when load is high. Even efforts to simplify a task by directing attention to relevant items may place an added burden if the working memory load of the task exceeds available resources.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0195', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'It is not particularly surprising that our general working memory measure was positively related to overall accuracy on our selective attention/working memory task. What is possibly surprising, however, is that no interaction occurred between general working memory and our attention-related task manipulation. The results suggest that there is an overall additive impact of resource demands on working memory performance. Many studies have been aimed at identifying unique cognitive constraints on working memory, including attention (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Cowan et al., 2010; Unsworth & Spillers, 2010',
#          'tag_attr': {'refid': ['b0105', 'b0305'], 'id': 'r0070'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '), storage capacity (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Cowan et al., 2010; Unsworth & Spillers, 2010',
#          'tag_attr': {'refid': ['b0105', 'b0305'], 'id': 'r0075'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '), and long-term knowledge (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Gathercole, 2006',
#          'tag_attr': {'refid': ['b0140'], 'id': 'c0270'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). The current findings, however, suggest that all of these factors (and others we have yet to identify) place a summative load on available resources. This notion is clearly consistent with resource-sharing accounts of working memory (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Barrouillet et al., 2004; Towse & Hitch, 1995',
#          'tag_attr': {'refid': ['b0055', 'b0300'], 'id': 'r0080'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') proposing that controlled attentional resources shift to meet the different demands of the task. Extending this, our results suggest no preferential access to available resources such that demands for selective attention do not take precedence over storage requirements or vice versa.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0200', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'Another important finding in the current study is that storage capacity influenced response times even when array sizes were individually adjusted according to each participant’s span length. In particular, our results reveal unique relationships between storage capacity and response to working memory load independent of attention. Specifically, long span individuals showed similar response times regardless of whether task demands differed in terms of attention or load. Short span individuals, on the other hand, made faster responses under low load conditions than under high load conditions. Importantly, these differences cannot be attributed to a selective attention deficit in short span individuals, as evidenced by the lack of an interaction between the number of shapes presented and span length in the accuracy data and the faster response times to 2 shapes as span decreased.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0205', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'The slower response times under high load conditions for short span individuals but not long span individuals suggests a cost for short span individuals in working under conditions that tax available resources, costs not evident in those with long spans. Although there was no impact on accuracy in our simple task requiring recall over a couple of seconds, the slower response times suggest that the short span individuals are less adept at working above their capacity. Why would this be so? One possibility could be that the demands of the high working memory load condition were greater for our short span individuals than for our long span individuals. Such an argument could apply if we had imposed one common high working memory load for all participants as has been done in many previous studies (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Cowan et al., 2010',
#          'tag_attr': {'refid': ['b0105'], 'id': 'c0275'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). If this were the case, some of our participants would have been working very much beyond their span and others possibly not. The design of the current study, however, essentially rules out explanations related to working memory load because we titrated load to each individual’s storage capacity. The load of the above span condition was similar across all participants. Although not directly tested in the current study, a more likely explanation is that these differences arise due to strategy use. It is possible that short span individuals are less efficient at refreshing memory, in using rehearsal strategies, or in allocating attention, leading to slower performance under conditions taxing available resources. Perhaps the most likely explanation, however, is suggested by the remarkable consistency in the performance of our long span individuals. These results suggest that long span individuals are particularly skilled at efficiently using strategies to manage a variety of task demands.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0210', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'One final question addressed in the current study was whether there was any evidence that language abilities were related to domain-general executive attention and working memory resources. The findings regarding performance accuracy provided no evidence for such a relationship. For response time, however, there was a complex interaction among language abilities, load, and span. Consider first the interaction between language abilities and load. There was no evidence of an overall slowing relative to typical language development by those with low language, a finding that would have been consistent with a general slowing account of SLI (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Kail, 1994',
#          'tag_attr': {'refid': ['b0170'], 'id': 'c0280'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). In fact, it was the relative impact of working above or within storage capacity that mattered. Faster responses under low load conditions were observed for those with typically developing good to strong language skills but not for those with low language abilities. Thus, poor language was associated with a relative failure to benefit from low load conditions.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0215', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'The relationship among language abilities, working memory load, and response time was also influenced by individuals’ span length. The most marked effect was for those with high storage capacity (spans of 8 or 9 items), which included one child who met the criterion for a language impairment; language abilities were inversely related to response time such that those with relatively poor language made slower responses regardless of working memory load. One possible explanation for this pattern could be related to the argument regarding strategy use made above. Individuals with long spans who have strong language skills may be particularly adept at employing strategies to assist them in managing the cognitive demands of a task. It might take more time for long span individuals with weaker language skills to encode, rehearse, or retrieve items from memory due to less efficient use of verbal self-cues.',
#          'init_args': (),
#          'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0220', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'Consistent with many language processing theories (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-refs',
#          'tag_text': '[Kelly & Martin, 1994; Saffran, 2003',
#          'tag_attr': {'refid': ['b0185', 'b0275'], 'id': 'r0085'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '), the current findings demonstrate a relationship between domain-general capacity-limited cognitive functioning and language abilities, albeit only in relation to response time. None of the differences related to language abilities resulted in reduced performance accuracy on our task even though those with poor language skills made slower responses in some cases. Nevertheless, it might be that the demands of our task were too simple and short-lived for the slower response times to affect performance. Over multiple steps completed slowly, those with poor language skills could fail to compete tasks as expected. The finding that language abilities were related to response time and not accuracy is more consistent with theories of SLI implicating generalized slowing in information processing (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Kail, 1994',
#          'tag_attr': {'refid': ['b0170'], 'id': 'c0285'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': ') than reduced capacity (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Bishop, 1992',
#          'tag_attr': {'refid': ['b0070'], 'id': 'c0290'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text',
#          'content': '). Nevertheless, the current results do not provide strong support for a generalized slowing account; children with poor language in the current study were not slower to respond than their peers. It was their peers who were faster to respond under low load conditions. On the other hand, our study did not provide a rigorous test of a generalized slowing account for SLI either. We measured response time. Many previous studies demonstrating slower responses in SLI than typically developing groups have employed reaction time paradigms that more directly test the fastest possible response after presentation of a stimulus (',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'cross-ref',
#          'tag_text': '[Miller et al., 2001',
#          'tag_attr': {'refid': ['b0225'], 'id': 'c0295'},
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'text', 'content': ').', 'init_args': (), 'init_kwargs': {}}],
#        'init_args': (),
#        'init_kwargs': {'id': 'p0225', 'view': 'all'}},
#       {'inline_list': [{'type': 'text',
#          'content': 'As is common in many studies of this type, the main limitation of the current study was the small sample size. One way that we attempted to combat this issue was to recruit participants with a broad range of language and working memory abilities. The resulting problem was an unbalanced design such that many more participants met criteria for typical development than language impairment or working memory impairment. To deal with this, we analyzed the data using linear mixed effects, a procedure that can accommodate both unbalanced designs and correlated observations. It could be argued that not having all participants complete the identical task with the same number of items is a limitation. Nevertheless, we had a strong rationale for adjusting task demands based on individual storage capacity. As a result, we argue that the high/low working memory load manipulation employed imposed uniformly high or low demands for all participants. Finally, the generalized measures of working memory and language included in the current study were administered up to 8 months prior to the experimental task. Given that the standardized tests employed used 12-month age bands for all ages tested and the age range of the participants (6–10',
#          'init_args': (),
#          'init_kwargs': {}},
#         {'type': 'tag',
#          'tag_name': 'hsp',
#          'tag_text': '',
#          'tag_attr': {'sp': '0.25'},
#          'init_args': (),
# ...
#          'title': {'maintitle': 'Sustained attention in children with specific language impairment'},
#          'series': '',
#          'date': '2009',
#          'pages': {'first-page': '915', 'last-page': '929'}},
#         'b0130': {'id': 'b0130',
#          'label': 'Fougnie, 2008',
#          'authors': [{'given-name': 'D.', 'surname': 'Fougnie'}],
#          'title': {'maintitle': 'The relationship between attention and working memory'},
#          'edited-book': '',
#          'pages': {'first-page': '1', 'last-page': '45'}},
#         'b0135': {'id': 'b0135',
#          'label': 'Gallinat and Spaulding, 2012',
#          'authors': [{'given-name': 'E.', 'surname': 'Gallinat'},
#           {'given-name': 'T.J.', 'surname': 'Spaulding'}],
#          'title': {'maintitle': 'Differences in the performance of children with specific language impairment and their typically developing peers on nonverbal cognitive tests: A meta-analysis'},
#          'series': '',
#          'date': '2012',
#          'pages': {'first-page': '1363', 'last-page': '1382'}},
#         'b0140': {'id': 'b0140',
#          'label': 'Gathercole, 2006',
#          'authors': [{'given-name': 'S.E.', 'surname': 'Gathercole'}],
#          'title': {'maintitle': 'Nonword repetition and word learning: The nature of the relationship'},
#          'series': '',
#          'date': '2006',
#          'pages': {'first-page': '513', 'last-page': '543'}},
#         'b0145': {'id': 'b0145',
#          'label': 'Gilchrist et al., 2008',
#          'authors': [{'given-name': 'A.L.', 'surname': 'Gilchrist'},
#           {'given-name': 'N.', 'surname': 'Cowan'},
#           {'given-name': 'M.', 'surname': 'Naveh-Benjamin'}],
#          'title': {'maintitle': 'Working memory capacity for spoken sentences decreases with adult aging: Recall of fewer, but not smaller, chunks in older adults'},
#          'series': '',
#          'date': '2008',
#          'pages': {'first-page': '773', 'last-page': '787'}},
#         'b0150': {'id': 'b0150',
#          'label': 'Grier, 1971',
#          'authors': [{'given-name': 'J.B.', 'surname': 'Grier'}],
#          'title': {'maintitle': 'Nonparametric indexes for sensitivity and bias: Computing formulas'},
#          'series': '',
#          'date': '1971',
#          'pages': {'first-page': '424', 'last-page': '429'}},
#         'b0155': {'id': 'b0155',
#          'label': 'Hambrick et al., 2005',
#          'authors': [{'given-name': 'D.Z.', 'surname': 'Hambrick'},
#           {'given-name': 'M.J.', 'surname': 'Kane'},
#           {'given-name': 'R.W.', 'surname': 'Engle'}],
#          'title': {'maintitle': 'The role of working memory in higher-level cognition: Domain-specific versus domain-general perspectives'},
#          'edited-book': '',
#          'pages': {'first-page': '104', 'last-page': '121'}},
#         'b0160': {'id': 'b0160',
#          'label': 'Huber, 2002',
#          'authors': [{'given-name': 'P.J.', 'surname': 'Huber'}],
#          'title': {'maintitle': 'John W. Tukey’s contributions to robust statistics'},
#          'series': '',
#          'date': '2002',
#          'pages': {'first-page': '1640', 'last-page': '1648'}},
#         'b0165': {'id': 'b0165',
#          'label': 'Kahneman, 1973',
#          'authors': [{'given-name': 'D.', 'surname': 'Kahneman'}],
#          'title': {'maintitle': 'Attention and effort'},
#          'book': ''},
#         'b0170': {'id': 'b0170',
#          'label': 'Kail, 1994',
#          'authors': [{'given-name': 'R.', 'surname': 'Kail'}],
#          'title': {'maintitle': 'A method for studying the generalized slowing hypothesis in children with specific language impairment'},
#          'series': '',
#          'date': '1994',
#          'pages': {'first-page': '418', 'last-page': '421'}},
#         'b0175': {'id': 'b0175',
#          'label': 'Kane and Engle, 2002',
#          'authors': [{'given-name': 'M.J.', 'surname': 'Kane'},
#           {'given-name': 'R.W.', 'surname': 'Engle'}],
#          'title': {'maintitle': 'The role of prefrontal cortex in working-memory capacity, executive attention, and general fluid intelligence: An individual differences perspective'},
#          'series': '',
#          'date': '2002',
#          'pages': {'first-page': '637', 'last-page': '671'}},
#         'b0180': {'id': 'b0180',
#          'label': 'Kane et al., 2004',
#          'authors': [{'given-name': 'M.J.', 'surname': 'Kane'},
#           {'given-name': 'D.Z.', 'surname': 'Hambrick'},
#           {'given-name': 'S.W.', 'surname': 'Tuholski'},
#           {'given-name': 'O.', 'surname': 'Wilhelm'},
#           {'given-name': 'T.W.', 'surname': 'Payne'},
#           {'given-name': 'R.W.', 'surname': 'Engle'}],
#          'title': {'maintitle': 'The generality of working memory capacity: A latent variable approach to verbal and visuospatial memory span and reasoning'},
#          'series': '',
#          'date': '2004',
#          'pages': {'first-page': '189', 'last-page': '217'}},
#         'b0185': {'id': 'b0185',
#          'label': 'Kelly and Martin, 1994',
#          'authors': [{'given-name': 'M.H.', 'surname': 'Kelly'},
#           {'given-name': 'S.', 'surname': 'Martin'}],
#          'title': {'maintitle': 'Domain-general abilities applied to domain-specific tasks: Sensitivity to probabilities in perception, cognition, and language'},
#          'series': '',
#          'date': '1994',
#          'pages': {'first-page': '105', 'last-page': '140'}},
#         'b0190': {'id': 'b0190',
#          'label': 'King and Just, 1991',
#          'authors': [{'given-name': 'J.', 'surname': 'King'},
#           {'given-name': 'M.A.', 'surname': 'Just'}],
#          'title': {'maintitle': 'Individual differences in syntactic processing: The role of working memory'},
#          'series': '',
#          'date': '1991',
#          'pages': {'first-page': '580', 'last-page': '602'}},
#         'b0195': {'id': 'b0195',
#          'label': 'Kuznetsova et al., 2014',
#          'textref': 'Kuznetsova, A., Brockhoff, P. B., & Christensen, R. H. B. (2014).'},
#         'b0200': {'id': 'b0200',
#          'label': 'Lavie, 2005',
#          'authors': [{'given-name': 'N.', 'surname': 'Lavie'}],
#          'title': {'maintitle': 'Distracted and confused? Selective attention under load'},
#          'series': '',
#          'date': '2005',
#          'pages': {'first-page': '75', 'last-page': '82'}},
#         'b0205': {'id': 'b0205',
#          'label': 'Lavie et al., 2004',
#          'authors': [{'given-name': 'N.', 'surname': 'Lavie'},
#           {'given-name': 'A.', 'surname': 'Hirst'},
#           {'given-name': 'J.W.', 'surname': 'de Fockert'},
#           {'given-name': 'E.', 'surname': 'Viding'}],
#          'title': {'maintitle': 'Load theory of selective attention and cognitive control'},
#          'series': '',
#          'date': '2004',
#          'pages': {'first-page': '339', 'last-page': '354'}},
#         'b0210': {'id': 'b0210',
#          'label': 'MacDonald and Christiansen, 2002',
#          'authors': [{'given-name': 'M.C.', 'surname': 'MacDonald'},
#           {'given-name': 'M.H.', 'surname': 'Christiansen'}],
#          'title': {'maintitle': 'Reassessing working memory: A comment on Just & Carpenter (1992) and Waters & Caplan (1996)'},
#          'series': '',
#          'date': '2002',
#          'pages': {'first-page': '35', 'last-page': '54'}},
#         'b0215': {'id': 'b0215',
#          'label': 'Martin and Ellis, 2012',
#          'authors': [{'given-name': 'K.I.', 'surname': 'Martin'},
#           {'given-name': 'N.C.', 'surname': 'Ellis'}],
#          'title': {'maintitle': 'The roles of phonological short-term memory and working memory in L2 grammar and vocabulary learning'},
#          'series': '',
#          'date': '2012',
#          'pages': {'first-page': '379', 'last-page': '413'}},
#         'b0220': {'id': 'b0220',
#          'label': 'Martinussen et al., 2005',
#          'authors': [{'given-name': 'R.', 'surname': 'Martinussen'},
#           {'given-name': 'J.', 'surname': 'Hayden'},
#           {'given-name': 'S.', 'surname': 'Hogg-Johnson'},
#           {'given-name': 'R.', 'surname': 'Tannock'}],
#          'title': {'maintitle': 'A meta-analysis of working memory impairments in children with attention-deficit/hyperactivity disorder'},
#          'series': '',
#          'date': '2005',
#          'pages': {'first-page': '377', 'last-page': '384'}},
#         'b0225': {'id': 'b0225',
#          'label': 'Miller et al., 2001',
#          'authors': [{'given-name': 'C.A.', 'surname': 'Miller'},
#           {'given-name': 'R.', 'surname': 'Kail'},
#           {'given-name': 'L.B.', 'surname': 'Leonard'},
#           {'given-name': 'J.B.', 'surname': 'Tomblin'}],
#          'title': {'maintitle': 'Speed of processing in children with specific language impairment'},
#          'series': '',
#          'date': '2001',
#          'pages': {'first-page': '416', 'last-page': '433'}},
#         'b0230': {'id': 'b0230',
#          'label': 'Nadler and Archibald, 2014',
#          'authors': [{'given-name': 'R.', 'surname': 'Nadler'},
#           {'given-name': 'L.', 'surname': 'Archibald'}],
#          'title': {'maintitle': 'The assessment of verbal and visuospatial working memory with school age Canadian children'},
#          'series': '',
#          'date': '2014',
#          'pages': {'first-page': '262', 'last-page': '279'}},
#         'b0235': {'id': 'b0235',
#          'label': 'Noonan et al., 2014',
#          'authors': [{'given-name': 'N.B.', 'surname': 'Noonan'},
#           {'given-name': 'S.M.', 'surname': 'Redmond'},
#           {'given-name': 'L.M.', 'surname': 'Archibald'}],
#          'title': {'maintitle': 'Contributions of children’s linguistic and working memory proficiencies to their judgments of grammaticality'},
#          'series': '',
#          'date': '2014',
#          'pages': {'first-page': '979', 'last-page': '989'}},
#         'b0240': {'id': 'b0240',
#          'label': 'Oberauer et al., 2003',
#          'authors': [{'given-name': 'K.', 'surname': 'Oberauer'},
#           {'given-name': 'H.M.', 'surname': 'Süβ'},
#           {'given-name': 'O.', 'surname': 'Wilhelm'},
#           {'given-name': 'W.W.', 'surname': 'Wittman'}],
#          'title': {'maintitle': 'The multiple faces of working memory: Storage, processing, supervision, and coordination'},
#          'series': '',
#          'date': '2003',
#          'pages': {'first-page': '167', 'last-page': '193'}},
#         'b0245': {'id': 'b0245',
#          'label': 'Parasuraman and Davies, 1984',
#          'edited-book': ''},
#         'b0250': {'id': 'b0250',
#          'label': 'Posner, 1978',
#          'authors': [{'given-name': 'M.I.', 'surname': 'Posner'}],
#          'title': {'maintitle': 'Chronometric explorations of mind'},
#          'book': ''},
#         'b0255': {'id': 'b0255',
#          'label': 'Posner and Petersen, 1990',
#          'authors': [{'given-name': 'M.I.', 'surname': 'Posner'},
#           {'given-name': 'S.E.', 'surname': 'Petersen'}],
#          'title': {'maintitle': 'The attention system of the human brain'},
#          'series': '',
#          'date': '1990',
#          'pages': {'first-page': '25', 'last-page': '42'}},
#         'b0260': {'id': 'b0260',
#          'label': 'R Core Team, 2013',
#          'textref': 'R Core Team. (2013).'},
#         'b0265': {'id': 'b0265',
#          'label': 'Redmond, 2005',
#          'authors': [{'given-name': 'S.M.', 'surname': 'Redmond'}],
#          'title': {'maintitle': 'Differentiating SLI from ADHD using children’s sentence recall and production of past tense morphology'},
#          'series': '',
#          'date': '2005',
#          'pages': {'first-page': '109', 'last-page': '127'}},
#         'b0270': {'id': 'b0270',
#          'label': 'Redmond et al., 2011',
#          'authors': [{'given-name': 'S.M.', 'surname': 'Redmond'},
#           {'given-name': 'H.L.', 'surname': 'Thompson'},
#           {'given-name': 'S.', 'surname': 'Goldstein'}],
#          'title': {'maintitle': 'Psycholinguistic profiling differentiates specific language impairment from typical development and from attention-deficit/hyperactivity disorder'},
#          'series': '',
#          'date': '2011',
#          'pages': {'first-page': '99', 'last-page': '117'}},
#         'b0275': {'id': 'b0275',
#          'label': 'Saffran, 2003',
#          'authors': [{'given-name': 'J.R.', 'surname': 'Saffran'}],
#          'title': {'maintitle': 'Statistical language learning: Mechanisms and constraints'},
#          'series': '',
#          'date': '2003',
#          'pages': {'first-page': '110', 'last-page': '114'}},
#         'b0280': {'id': 'b0280',
#          'label': 'Schneider et al., 2002',
#          'authors': [{'given-name': 'W.', 'surname': 'Schneider'},
#           {'given-name': 'A.', 'surname': 'Eschman'},
#           {'given-name': 'A.', 'surname': 'Zuccolotto'}],
#          'title': {'maintitle': 'E-Prime user’s guide'},
#          'book': ''},
#         'b0285': {'id': 'b0285',
#          'label': 'Schweizer and Moosbrugger, 2004',
#          'authors': [{'given-name': 'K.', 'surname': 'Schweizer'},
#           {'given-name': 'H.', 'surname': 'Moosbrugger'}],
#          'title': {'maintitle': 'Attention and working memory as predictors of intelligence'},
#          'series': '',
#          'date': '2004',
#          'pages': {'first-page': '329', 'last-page': '347'}},
#         'b0290': {'id': 'b0290',
#          'label': 'Semel et al., 2003',
#          'authors': [{'given-name': 'E.', 'surname': 'Semel'},
#           {'given-name': 'E.H.', 'surname': 'Wiig'},
#           {'given-name': 'W.A.', 'surname': 'Secord'}],
#          'title': {'maintitle': 'Clinical evaluation of language fundamentals'},
#          'book': ''},
#         'b0295': {'id': 'b0295',
#          'label': 'Shiffrin, 1988',
#          'authors': [{'given-name': 'R.M.', 'surname': 'Shiffrin'}],
#          'title': {'maintitle': 'Attention'},
#          'edited-book': '',
#          'pages': {'first-page': '739', 'last-page': '811'}},
#         'b0300': {'id': 'b0300',
#          'label': 'Towse and Hitch, 1995',
#          'authors': [{'given-name': 'J.N.', 'surname': 'Towse'},
#           {'given-name': 'G.J.', 'surname': 'Hitch'}],
#          'title': {'maintitle': 'Is there a relationship between task demand and storage space in tests of working memory capacity?'},
#          'series': '',
#          'date': '1995',
#          'pages': {'first-page': '108', 'last-page': '124'}},
#         'b0305': {'id': 'b0305',
#          'label': 'Unsworth and Spillers, 2010',
#          'authors': [{'given-name': 'N.', 'surname': 'Unsworth'},
#           {'given-name': 'G.J.', 'surname': 'Spillers'}],
#          'title': {'maintitle': 'Working memory capacity: Attention control, secondary memory, or both? A direct test of the dual-component model'},
#          'series': '',
#          'date': '2010',
#          'pages': {'first-page': '392', 'last-page': '406'}},
#         'b0310': {'id': 'b0310',
#          'label': 'Vandewalle et al., 2012',
#          'authors': [{'given-name': 'E.', 'surname': 'Vandewalle'},
#           {'given-name': 'B.', 'surname': 'Boets'},
#           {'given-name': 'P.', 'surname': 'Ghesquière'},
#           {'given-name': 'I.', 'surname': 'Zink'}],
#          'title': {'maintitle': 'Auditory processing and speech perception in children with specific language impairment: Relations with oral language and literacy skills'},
#          'series': '',
#          'date': '2012',
#          'pages': {'first-page': '635', 'last-page': '644'}},
#         'b0320': {'id': 'b0320',
#          'label': 'Vogel et al., 2005',
#          'authors': [{'given-name': 'E.K.', 'surname': 'Vogel'},
#           {'given-name': 'A.W.', 'surname': 'McCollough'},
#           {'given-name': 'M.G.', 'surname': 'Machizawa'}],
#          'title': {'maintitle': 'Neural measures reveal individuals’ differences in controlling access to working memory'},
#          'series': '',
#          'date': '2005',
#          'pages': {'first-page': '500', 'last-page': '503'}},
#         'b0325': {'id': 'b0325',
#          'label': 'Wechsler, 1999',
#          'authors': [{'given-name': 'D.', 'surname': 'Wechsler'}],
#          'title': {'maintitle': 'Wechsler Abbreviated Scale of Intelligence'},
#          'book': ''}}}},
#      'init_args': (),
#      'init_kwargs': {}}}]})

# %% [markdown]
# ### 使用read_docset来将输出转换为DocumentSet

# %%
doc_set = ds.read_docset()

# %%
len(doc_set)
# Out:
# 141

# %% [markdown]
# ## 文档集可迭代

# %%
doc_name, doc = next(iter(doc_set.items()))

# %%
print(doc.get_text())
# Out:
# Introduction
# Attention allocation, updating working memory, and language processing are interdependent cognitive tasks related to the focused direction of limited resources, refreshing and substituting information in the current focus of attention, and receiving/sending verbal communication, respectively. These systems are probably impossible to study in isolation, which makes interpretation of findings related to any one of them challenging. For example, we know that children with an unexpected and disproportionate impairment in language development known as specific language impairment (SLI) show deficits relative to age-matched peers on measures of attention ([Finneran, Francis, & Leonard, 2009) and working memory ([Archibald & Gathercole, 2007). Despite efforts to employ nonlinguistic tasks in these studies, the interdependency of the cognitive systems supporting working memory, attention, and language processing makes it difficult to rule out entirely explanations related to the language deficit in SLI. Another concern arising from these studies relates to the potential discrepancy in the cognitive load imposed by the tasks on children with and without impairments. Even in cases where children with impairments perform accurately, the cognitive load of the task may be higher, requiring the recruitment of additional or alternate resources. The current study provided a systematic examination of the relationship among working memory skills, language abilities, and cognitive functioning by examining whether performance on a selective attention task imposing varying but individually adjusted memory demands is dependent on working memory and/or language abilities in children with and without impairments.
# Attention is viewed as a limited capacity system (e.g.,[Kahneman, 1973; Lavie, 2005; Lavie, Hirst, de Fockert, & Viding, 2004) that consists of multiple components, including the ability to focus, sustain, and switch mental focus ([Parasuraman & Davies, 1984; Posner, 1978; Shiffrin, 1988). Essentially, in functional terms, attention refers to the ability to selectively process information, a critical aspect of our cognitive capacities ([Fougnie, 2008). Attentional functions performed by distinct networks include alerting to achieve a general state of responsiveness to sensory stimulation, orienting to a subset of sensory information for privileged processing, and executive attention acting on post-sensory representations when competition exists for access to a central, limited-capacity system ([Fan, McCandliss, Sommer, Raz, & Posner, 2002; Posner & Petersen, 1990). Executive attention is considered a domain-general resource shared broadly in post-perceptual cognitive tasks such as those under study in the current work.
# Another critical aspect of our cognitive capacities is working memory, the ability to retain task-relevant information in a highly activated and accessible state over time ([Hambrick, Kane, & Engle, 2005; Kane & Engle, 2002). One key component of working memory is a controlled attentional resource responsible for the coordination of storage and processing within working memory ([Bayliss, Jarrold, Gunn, & Baddeley, 2003; Engle, Tuholski, Laughlin, & Conway, 1999; Kane et al., 2004). There is clearly a role for the executive attentional resource described above in the notion of a controlled attentional resource or “central executive” ([Baddeley & Hitch, 1974) in working memory. Indeed, many studies have demonstrated the close relationship between attention and working memory ([Bleckley, Durso, Crutchfield, Engle, & Khanna, 2003; Martinussen, Hayden, Hogg-Johnson, & Tannock, 2005; Vogel, McCollough, & Machizawa, 2005).
# Nevertheless, the constructs of executive attention and the central executive of working memory are not entirely isomorphic. The central executive of working memory is a broader concept incorporating responsibility for the monitoring of ongoing cognitive processes and actions, the selective activation of relevant representations and procedures, and the suppression of irrelevant, distracting ones ([Oberauer, Süβ, Wilhelm, & Wittman, 2003). Beyond the theoretical distinctions, however, it is challenging to empirically demonstrate the unique contributions of executive attention and central executive/working memory processes. In one study of healthy adults, the best model of the data included both attention and working memory as separate predictors of intelligence ([Schweizer & Moosbrugger, 2004). In the current study, we further examined the relationship between attention and working memory by having participants complete a selective attention task under different working memory loads while individually equating the demands of another component of working memory, short-term storage.
# The operation of the central executive of working memory on relevant stimuli necessitates the retention of those stimuli in an accessible state. These basic memory abilities are the second main component of working memory and are conceived of as short-term memory stores ([Baddeley & Hitch, 1974) or a functional store composed of an activated subset of information held in long-term memory ([Cowan, 1999). It is generally agreed that there is some domain specificity in the short-term storage of information. According to one of the most prominent working memory models ([Baddeley, 1986; Baddeley & Hitch, 1974), distinct phonological and visuospatial short-term memory stores support retention. Other models account for domain specificity in working memory by allowing for interference between similar representations ([Cowan, 1999) and the influence of domain-specific cognitive operations such as verbal rehearsal and chunking of spatial patterns ([Oberauer et al., 2003).
# There is now considerable evidence that working memory involves some resource sharing; that is, there is some trade-off between the storage and processing demands of working memory tasks ([Barrouillet, Bernardin, & Camos, 2004). According to these accounts, controlled attentional resources shift from the processing demands of the task to the refreshing or rehearsal of the material in storage ([Barrouillet et al., 2004; Case, Kurland, & Goldberg, 1982; Towse & Hitch, 1995). It follows from this that individual differences, both in the capacity for storage and in controlled attention, constrain performance. To focus on the controlled attentional resource in working memory in the current study, we employed a novel approach involving equating storage demands across individuals.
# Language processing is a broad term encompassing the complex computational knowledge base required to send and receive verbal messages using phonological, mophosyntactic, semantic, and other conventions. Language learning places high demands on domain-general information processing abilities; language stimuli must be quickly encoded and retained, placing a load on the speed or capacity of online processing resources. Consistent with this view, current language processing theories incorporate domain-general mechanisms. For example, recent language acquisition theories include a domain-general statistical or probabilistic learning mechanism ([Saffran, 2003). As well, all sentence parsing models include a limited-capacity memory constraint characteristic of general cognition ([Kelly & Martin, 1994).
# It has been suggested that working memory supports language learning ([Baddeley, 2003). Ample evidence links working memory to language comprehension and expression in first language learners ([Gilchrist, Cowan, & Naveh-Benjamin, 2008; King & Just, 1991) and second language learners ([Andersson, 2010; Martin & Ellis, 2012). Findings of a relationship between language performance and verbal working memory measures, however, do not clearly demonstrate a role of working memory in supporting language learning. Indeed, researchers have argued that all of these tasks tap a single language processing resource ([Caplan & Waters, 1999; MacDonald & Christiansen, 2002). Evidence of a relationship between language abilities and a domain-general working memory component would be strengthened by findings of links between language performance and nonlinguistic working memory tasks, as investigated in the current study. It is important to remember the multiple components of working memory here and that the short-term storage component is considered domain specific. Many studies have demonstrated strong links between measures of phonological processing and language abilities ([Coady, 2013; Gathercole, 2006; Vandewalle, Boets, Ghesquière, & Zink, 2012). It follows from this that individual differences in domain-specific storage capacity could account for the previously established links between language and working memory. To focus on the relationship between language performance and domain-general central executive or executive attention processes, storage demands must be equated across participants as in the current study.
# One additional line of evidence for the relationship among attention, working memory, and language processing comes from children with impairments. Children with SLI have a disproportionate impairment in language learning. Nevertheless, nonlinguistic deficits in children who meet criteria for SLI are commonly reported ([Gallinat & Spaulding, 2012). Indeed, lower performance by SLI groups relative to age-matched typically developing groups has been found for measures of attention ([Finneran et al., 2009), working memory ([Archibald & Gathercole, 2007), and processing speed ([Miller, Kail, Leonard, & Tomblin, 2001). Such findings have led to the suggestion that a domain-general impairment in information processing speed ([Kail, 1994) or capacity ([Bishop, 1992) underlies SLI. Once again, however, examining the relationships between language and cognitive functioning is challenged by the overlap in task demands often tapping each of these systems. In one of the first studies to systematically differentiate children with language impairments with or without working memory impairments,[Noonan, Redmond, and Archibald (2014) demonstrated unique impacts on grammaticality judgment of these separable impairments. The findings are important because they highlight the interdependency of the systems but provide evidence against a causal connection between a working memory impairment and SLI. Consistent with this notion, poorer scores have been found for children with attention deficit disorders relative to age-matched peers on measures of language even though many of these children do not meet criteria for SLI ([Redmond, 2005; Redmond, Thompson, & Goldstein, 2011).
# The aim of the current study was to systematically examine the relationship among executive attention, working memory executive skills, and language abilities with short-term memory demands individually adjusted across participants. To do this, we adapted a procedure employed by Cowan and colleagues ([Cowan, Morey, AuBuchon, Zwilling, & Gilchrist, 2010) to investigate whether executive attention or storage capacity accounted for the developmental increase in working memory across three groups: young children aged 6 or 7years, older children aged 12 or 13years, and adults. In Cowan and colleagues’ study, an array of different colored items was presented, including either one shape (i.e., all circles) or two shapes (i.e., circles and triangles), followed by an array including a single shape. Participants were instructed to attend to one shape only (e.g., the circles) and to decide whether the shape in the second array was identical to the one that had been in the same location in the previous array. Attention was manipulated by including one shape (all target shapes) or two shapes (target plus distractor shapes) such that if distractor shapes could be ignored, fewer items would need to be retained in memory. Working memory load was manipulated by varying the number of total shapes in the array. A disproportionate attention-related effect was found for the young group relative to both the older child and adult groups under conditions of high working memory load (six items in an array) but not low working memory load (four items). The results were suggested to indicate that a fundamental storage capacity difference accounts for the developmental increase in working memory capacity and that attentional control was present in young children provided that working memory load was minimized. These findings further underscore the need to adjust storage demands based on individual short-term memory capacity as in the current study.
# In the current study, school-age children completed a selective attention task under individually determined high or low working memory load conditions following[Cowan and colleagues (2010) as well as measures of working memory capacity and language abilities. The first goal was to examine the interaction between selective attention and working memory load. A cost of the attention manipulation was expected in the high working memory condition but not in the low working memory condition. The reasoning was that the cost of additional attentional control would not exceed working memory capacity in the low load condition, resulting in no performance decrement, whereas the cost would exceed working memory capacity in the high load condition, impairing recall accuracy. A second aim was to evaluate whether general working memory capacity or language ability measures were related to the processing time or accuracy of responses. We expected an interaction between measures of working memory capacity and performance on our selective attention task. An attention-related advantage was expected for individuals with high working memory capacity over those with low working memory capacity given their greater available resources. No predictive hypothesis was established regarding language abilities. The role of a domain-general mechanism related to attention or working memory in language learning would be supported by results indicating a relationship between our measures of language abilities and our nonlinguistic selective attention/working memory task.
# Method
# Results
# Discussion
# The current study systematically examined the relationships among selective attention, working memory, and language abilities in school-age children. Performance accuracy differences were evident when selective attention was required, resulting in a cost under conditions of high working memory load but not low working memory load. As well, general working memory but not language abilities were positively related to overall accuracy on the experimental selective attention task regardless of the load, selective attention requirements, or span length at which the task was completed. Differences in response times based on task load and selective attention requirements were influenced by an individual’s storage capacity. For those with short spans, response time was faster under low load conditions and faster when 2 shapes were present. Those with long spans, however, were relatively impervious to the load and attention manipulation, showing no systematic difference in response time when working above or within span or when viewing 1 or 2 shapes. Language abilities but not general working memory skills were related to response times on the task in somewhat complex ways. Generally speaking, those with lower language scores completed the task more slowly, a difference that was particularly marked for those with long spans.
# First, consider the results related to demands for selective attention. When the total number of items presented was within the individual’s storage capacity such that the working memory load imposed was low, the requirements for selective attention had no significant impact on performance accuracy. Conversely, when the total number of items presented exceeded the individual’s storage capacity such that the working memory load imposed was high, there was a selective attention cost, resulting in less accurate performance. The interpretation here is quite clear. When working below span, sufficient resources were available to do the task regardless of whether distractor shapes were present or not. When working above span, however, sufficient resources were not available, resulting in impaired filtering. As a result, irrelevant items could not be filtered out, leading participants to attempt to retain both target and distractor shapes. Notice that the argument is not simply that efforts to filter were abandoned, which would render the 1 shape–above span and 2 shapes–above span conditions equal in terms of the total number of items to be retained. Rather, the reduced accuracy in the above span–2 shapes condition indicates an attention-related cost. The effort of trying to filter out irrelevant items in conjunction with insufficient memory resources resulted in impaired attentional control.
# These findings are consistent with those reported by[Cowan and colleagues (2010) using a similar paradigm. In their study, no group differences between their young children (6 or 7years), older children (11 or 12years), and adults were observed when completing their selective attention task on small arrays (4 items), whereas significantly lower scores were found for the young group only on larger arrays (6 items). As with our findings, filtering was impaired when working above span for the youngest group in Cowan and colleagues’ study and more generally in our study. It could be argued that the lack of an attention-related cost in the older groups in Cowan and colleagues’ study was due to the design not including above span arrays for these groups. The maximum array administered by Cowan and colleagues had 6 items, which was lower than the average span of the children in the current study. It might also be the case that the individually adjusted span lengths corresponding to high and low working memory load in the current study more clearly revealed the costs of selective attention demands when working above span. Our findings provide clear evidence of an interaction between executive attention and working memory load such that attentional costs occur only when load is high. Even efforts to simplify a task by directing attention to relevant items may place an added burden if the working memory load of the task exceeds available resources.
# It is not particularly surprising that our general working memory measure was positively related to overall accuracy on our selective attention/working memory task. What is possibly surprising, however, is that no interaction occurred between general working memory and our attention-related task manipulation. The results suggest that there is an overall additive impact of resource demands on working memory performance. Many studies have been aimed at identifying unique cognitive constraints on working memory, including attention ([Cowan et al., 2010; Unsworth & Spillers, 2010), storage capacity ([Cowan et al., 2010; Unsworth & Spillers, 2010), and long-term knowledge ([Gathercole, 2006). The current findings, however, suggest that all of these factors (and others we have yet to identify) place a summative load on available resources. This notion is clearly consistent with resource-sharing accounts of working memory ([Barrouillet et al., 2004; Towse & Hitch, 1995) proposing that controlled attentional resources shift to meet the different demands of the task. Extending this, our results suggest no preferential access to available resources such that demands for selective attention do not take precedence over storage requirements or vice versa.
# Another important finding in the current study is that storage capacity influenced response times even when array sizes were individually adjusted according to each participant’s span length. In particular, our results reveal unique relationships between storage capacity and response to working memory load independent of attention. Specifically, long span individuals showed similar response times regardless of whether task demands differed in terms of attention or load. Short span individuals, on the other hand, made faster responses under low load conditions than under high load conditions. Importantly, these differences cannot be attributed to a selective attention deficit in short span individuals, as evidenced by the lack of an interaction between the number of shapes presented and span length in the accuracy data and the faster response times to 2 shapes as span decreased.
# The slower response times under high load conditions for short span individuals but not long span individuals suggests a cost for short span individuals in working under conditions that tax available resources, costs not evident in those with long spans. Although there was no impact on accuracy in our simple task requiring recall over a couple of seconds, the slower response times suggest that the short span individuals are less adept at working above their capacity. Why would this be so? One possibility could be that the demands of the high working memory load condition were greater for our short span individuals than for our long span individuals. Such an argument could apply if we had imposed one common high working memory load for all participants as has been done in many previous studies ([Cowan et al., 2010). If this were the case, some of our participants would have been working very much beyond their span and others possibly not. The design of the current study, however, essentially rules out explanations related to working memory load because we titrated load to each individual’s storage capacity. The load of the above span condition was similar across all participants. Although not directly tested in the current study, a more likely explanation is that these differences arise due to strategy use. It is possible that short span individuals are less efficient at refreshing memory, in using rehearsal strategies, or in allocating attention, leading to slower performance under conditions taxing available resources. Perhaps the most likely explanation, however, is suggested by the remarkable consistency in the performance of our long span individuals. These results suggest that long span individuals are particularly skilled at efficiently using strategies to manage a variety of task demands.
# One final question addressed in the current study was whether there was any evidence that language abilities were related to domain-general executive attention and working memory resources. The findings regarding performance accuracy provided no evidence for such a relationship. For response time, however, there was a complex interaction among language abilities, load, and span. Consider first the interaction between language abilities and load. There was no evidence of an overall slowing relative to typical language development by those with low language, a finding that would have been consistent with a general slowing account of SLI ([Kail, 1994). In fact, it was the relative impact of working above or within storage capacity that mattered. Faster responses under low load conditions were observed for those with typically developing good to strong language skills but not for those with low language abilities. Thus, poor language was associated with a relative failure to benefit from low load conditions.
# The relationship among language abilities, working memory load, and response time was also influenced by individuals’ span length. The most marked effect was for those with high storage capacity (spans of 8 or 9 items), which included one child who met the criterion for a language impairment; language abilities were inversely related to response time such that those with relatively poor language made slower responses regardless of working memory load. One possible explanation for this pattern could be related to the argument regarding strategy use made above. Individuals with long spans who have strong language skills may be particularly adept at employing strategies to assist them in managing the cognitive demands of a task. It might take more time for long span individuals with weaker language skills to encode, rehearse, or retrieve items from memory due to less efficient use of verbal self-cues.
# Consistent with many language processing theories ([Kelly & Martin, 1994; Saffran, 2003), the current findings demonstrate a relationship between domain-general capacity-limited cognitive functioning and language abilities, albeit only in relation to response time. None of the differences related to language abilities resulted in reduced performance accuracy on our task even though those with poor language skills made slower responses in some cases. Nevertheless, it might be that the demands of our task were too simple and short-lived for the slower response times to affect performance. Over multiple steps completed slowly, those with poor language skills could fail to compete tasks as expected. The finding that language abilities were related to response time and not accuracy is more consistent with theories of SLI implicating generalized slowing in information processing ([Kail, 1994) than reduced capacity ([Bishop, 1992). Nevertheless, the current results do not provide strong support for a generalized slowing account; children with poor language in the current study were not slower to respond than their peers. It was their peers who were faster to respond under low load conditions. On the other hand, our study did not provide a rigorous test of a generalized slowing account for SLI either. We measured response time. Many previous studies demonstrating slower responses in SLI than typically developing groups have employed reaction time paradigms that more directly test the fastest possible response after presentation of a stimulus ([Miller et al., 2001).
# As is common in many studies of this type, the main limitation of the current study was the small sample size. One way that we attempted to combat this issue was to recruit participants with a broad range of language and working memory abilities. The resulting problem was an unbalanced design such that many more participants met criteria for typical development than language impairment or working memory impairment. To deal with this, we analyzed the data using linear mixed effects, a procedure that can accommodate both unbalanced designs and correlated observations. It could be argued that not having all participants complete the identical task with the same number of items is a limitation. Nevertheless, we had a strong rationale for adjusting task demands based on individual storage capacity. As a result, we argue that the high/low working memory load manipulation employed imposed uniformly high or low demands for all participants. Finally, the generalized measures of working memory and language included in the current study were administered up to 8 months prior to the experimental task. Given that the standardized tests employed used 12-month age bands for all ages tested and the age range of the participants (6–10years), these data were considered sufficient to capture the true individual differences in language and working memory in the sample.
# The results of this study have important clinical and educational implications. First and foremost, the findings highlight the vulnerability of working above span, especially for those with low storage capacities. Cognitive demands were additive in the current study such that attention-related and storage-related requirements affected working memory performance. Importantly, even attempts to help a child through a task may do nothing but add additional, and unachievable, demands when the child is working beyond his or her working memory storage capacity. In our study, the effort to direct attention to the important information used up precious resources and resulted in lower recall accuracy when working above span. Speed of responding to varying cognitive loads was associated with language abilities in the current study. Those with good language skills were able to respond faster when cognitive load was low. It may be that effective strategy use is facilitated by linguistic abilities and that those with poor language may benefit from direct teaching of strategies.
# The current study investigated the relationship among executive attention, working memory, and language abilities in school-age children. The ability to selectively attend to target shapes depended on whether the task was being completed above or below span. When working within available storage capacity, selective attention demands had no impact on performance, whereas when working beyond available storage capacity, there was a cost due to the inability to filter out irrelevant items and the associated effort. Another novel finding was related to the impact on response times of working beyond available short-term memory capacity. Those with high storage capacity were relatively impervious to above span demands, maintaining performance response times despite the increased load. On the other hand, high load imposed a cost on those with low storage capacity, resulting in slower responses. There was a positive overall relationship between the experimental task and a generalized working memory measure, suggesting that the impact of attention-related and storage demands are additive with no preferential access to available resources. Finally, language abilities were associated with speed of responses but not accuracy and depended on the cognitive load of the task. These findings provide only limited evidence for a domain-general mechanism in language learning.

# %% [markdown]
# ## 分节

# %%
doc = doc_set[('_default', '68')]

# %%
doc.get_sections()
# Out:
# [<data_platform.document.Section at 0x1d23648d828>,
#  <data_platform.document.Section at 0x1d2364951d0>,
#  <data_platform.document.Section at 0x1d2364959e8>,
#  <data_platform.document.Section at 0x1d23649f400>]

# %%
sec = doc[0]
sec._init_kwargs
# Out:
# {'section_title': 'Materials and Methods', 'id': 'sec1', 'view': 'all'}

# %%
print(sec.get_text())
# Out:
# Materials and Methods
# After Institutional Review Board approval, data were extracted from the Richard L. Roudebush Veterans Administration Medical Center in Indianapolis, Indiana. The data for this study were obtained from an ongoing study of first-time colonoscopy. All data extracted were in electronic format. Inclusion and exclusion criteria were previously selected, and the test characteristics were not explicitly outlined for this study and were applied by using custom fully electronic software as part of the parent study design.
# Inclusion criteria for the parent study cohort included all veterans aged 40 years and older who had an index outpatient colonoscopy between 2002 and 2009 for any indication.
# Exclusion criteria for the cohort included (1) previous Veterans Health Administration–based colonoscopy, (2) indication for colonoscopy of surveillance for neoplasia, (3) surgical resection of any part of the large intestine, (4) history of polyps or cancer of the colon or rectum, (5) history of Crohn's disease, ulcerative colitis, or inflammatory bowel disease, (6) history of hereditary polyposis syndrome, (7) history of hereditary nonpolyposis colon cancer syndrome, or (8) having a colonoscopy earlier within the 8-year sampling frame (eg, a person with 2 colonoscopies within the sampling frame would have the second excluded).
# The extracted reports were linked as part of the parent study by using study-specific software to their corresponding pathology reports and de-identified for NLP analysis. There were 10,798 reports, with 6379 linked to pathology. Five hundred of the reports with linked pathology were randomly selected by using MySQL random record selection for triplicate manual annotation.[Figure 1 shows the flow chart for the study.
# The 500 reports and their linked pathology were combined into a single text document. Each document had a unique document ID and 4 sections: findings, impression, specimen, and pathology.
# To analyze the reports, clinical Text Analysis and Knowledge Extraction System (cTAKES), an open-source, freely available, Java-based NLP engine developed originally by the Mayo Clinic,[20] was used. It was written on top of the Unstructured Information Management Architecture framework.[21] cTAKES was designed to process clinical notes and uses named entity recognition to map identified concepts to the UMLS Metathesaurus,[22,23] a large, multipurpose, and multilingual thesaurus that contains millions of biomedical and health-related concepts, their synonymous names, and their relationships.[24] This entity recognition allows for capture of key clinical concepts to a standardized format for secondary usage (eg, UMLS CUI). cTAKES also determines if the named entity is negated as well as the context of the named entity within the document to allow for more robustness than simple text mining strategies.
# UMLS concepts were then matched against relevant terms such as “tubulovillous adenoma” for CUI C0334307. If the CUI was negated, it was excluded. These terms were searched and written to an NLP key. Sequential searching was used to identify the highest level of pathology from carcinoma to normal mucosa and included size identification to further classify the concept.
# Definitions were agreed to a priori for the terms for each concept. The highest level of pathology was divided into 5 categories: (1) carcinoma, (2) advanced adenoma, (3) nonadvanced adenoma, (4) hyperplastic polyp, and (5) normal mucosa/nonsignificant. Sessile serrated polyps were included within the adenoma category. Advanced adenomas were defined as those with villous features, carcinoma in situ, high-grade dysplasia, or adenoma with size on colonoscopy report ≥10 mm with size determined by the endoscopist. Nonsignificant findings included lipomas, benign colonic tissue, or no specimen for pathologic review.
# The location of the most advanced lesion was defined as proximal (cecum to and including splenic flexure), distal (descending colon to and including the rectum), and both proximal and distal equivalent for most advanced lesions.
# The largest adenoma removed and the total number of adenomas removed were captured. Presence and absence of hemorrhoids and diverticulosis were captured.
# Three of the authors (T.D.I., T.F.I., and C.K.) independently manually reviewed all 500 randomized documents and their associated pathology reports to determine the (1) highest level of pathology, (2) number of adenomas removed, (3) size of adenoma removed, (4) location of adenoma, and (5) presence of diverticulosis and hemorrhoids.
# Recall, precision, accuracy, and f-measure were calculated for both the testing and training data sets. Recall was defined as [true positives/(true positives + false negatives)] or (reports in agreement/positive reports by gold standard). Precision was defined as [true positives/(true positives + false positives)] or (reports in agreement/positive reports by NLP). Accuracy was defined as [(true positives + true negatives)/(true positives + false positives + true negatives + false negatives)]. The f-measure is defined as [2 * (precision * recall)/(precision + recall)] and is used for the measurement of information retrieval and measures the effectiveness of retrieval.[25] The values for recall, precision, accuracy, and f-measure vary between 0–1, with 1 being the optimal.
# One hundred fifty of the annotated samples were used for NLP training, with blinding to the other annotated documents. All 500 annotated gold standard documents were used for testing. Annotated linked colonoscopy and pathology reports were then run through the NLP engine to capture the highest level of pathology and previously defined concepts.

# %% [markdown]
# ## 段落

# %%
para1 = sec[0]
para1._init_kwargs
# Out:
# {}

# %%
print(para1.get_text())
# Out:
# Materials and Methods

# %%
para2 = sec[1]
para2._init_kwargs
# Out:
# {'id': 'p0035', 'view': 'all'}

# %%
print(para2.get_text())
# Out:
# After Institutional Review Board approval, data were extracted from the Richard L. Roudebush Veterans Administration Medical Center in Indianapolis, Indiana. The data for this study were obtained from an ongoing study of first-time colonoscopy. All data extracted were in electronic format. Inclusion and exclusion criteria were previously selected, and the test characteristics were not explicitly outlined for this study and were applied by using custom fully electronic software as part of the parent study design.

# %% [markdown]
# ## 行内元素

# %%
type(sec[4][0])
# Out:
# data_platform.document.Text

# %%
print(sec[4][0].get_text())
# Out:
# The extracted reports were linked as part of the parent study by using study-specific software to their corresponding pathology reports and de-identified for NLP analysis. There were 10,798 reports, with 6379 linked to pathology. Five hundred of the reports with linked pathology were randomly selected by using MySQL random record selection for triplicate manual annotation.

# %%
type(sec[4][1])
# Out:
# data_platform.document.Tag

# %%
print(sec[4][1].get_text())
# Out:
# [Figure 1

# %%
print(sec[4][1].tag_name)
print(sec[4][1].tag_text)
print(sec[4][1].tag_attr)
# Out:
# cross-ref
# [Figure 1
# {'refid': ['fig1']}

# %% [markdown]
# ## 引文数据

# %%
doc.metadatas
# Out:
# {'coredata': <data_platform.document.MetaData at 0x1d23649f550>,
#  'bib2para': <data_platform.document.MetaData at 0x1d23649f588>,
#  'references': <data_platform.document.MetaData at 0x1d23649f5c0>}

# %%
ref = doc.metadatas['references']
ref.meta_dict
# Out:
# {'id': 'bibl0005',
#  'view': 'all',
#  'section-title': {'text': 'References'},
#  'bibbliography-section': {'id': 'bibs0005',
#   'references': {'bib1': {'id': 'bib1',
#     'label': '1',
#     'authors': [{'given-name': 'L.C.', 'surname': 'Seeff'},
#      {'given-name': 'T.B.', 'surname': 'Richards'},
#      {'given-name': 'J.A.', 'surname': 'Shapiro'}],
#     'title': {'maintitle': 'How many endoscopies are performed for colorectal cancer screening?',
#      'subtitle': "Results from CDC's survey of endoscopic capacity"},
#     'series': '',
#     'date': '2004',
#     'pages': {'first-page': '1670', 'last-page': '1677'}},
#    'bib2': {'id': 'bib2',
#     'label': '2',
#     'authors': [{'given-name': 'C.J.', 'surname': 'Kahi'},
#      {'given-name': 'T.F.', 'surname': 'Imperiale'}],
#     'title': {'maintitle': 'Flexible sigmoidoscopy screening reduced colorectal cancer incidence and mortality in older adults'},
#     'series': '',
#     'date': '2012'},
#    'bib3': {'id': 'bib3',
#     'label': '3',
#     'authors': [{'given-name': 'R.E.', 'surname': 'Schoen'},
#      {'given-name': 'P.F.', 'surname': 'Pinsky'},
#      {'given-name': 'J.L.', 'surname': 'Weissfeld'}],
#     'title': {'maintitle': 'Colorectal-cancer incidence and mortality with screening flexible sigmoidoscopy'},
#     'series': '',
#     'date': '2012',
#     'pages': {'first-page': '2345', 'last-page': '2357'}},
#    'bib4': {'id': 'bib4',
#     'label': '4',
#     'authors': [{'given-name': 'A.G.', 'surname': 'Zauber'},
#      {'given-name': 'S.J.', 'surname': 'Winawer'},
#      {'given-name': 'M.J.', 'surname': "O'Brien"}],
#     'title': {'maintitle': 'Colonoscopic polypectomy and long-term prevention of colorectal-cancer deaths'},
#     'series': '',
#     'date': '2012',
#     'pages': {'first-page': '687', 'last-page': '696'}},
#    'bib5': {'id': 'bib5',
#     'label': '5',
#     'authors': [],
#     'title': {'maintitle': 'Screening for colorectal cancer: recommendation and rationale'},
#     'series': '',
#     'date': '2002',
#     'pages': {'first-page': '129', 'last-page': '131'}},
#    'bib6': {'id': 'bib6',
#     'label': '6',
#     'authors': [{'given-name': 'B.', 'surname': 'Levin'},
#      {'given-name': 'D.A.', 'surname': 'Lieberman'},
#      {'given-name': 'B.', 'surname': 'McFarland'}],
#     'title': {'maintitle': 'Screening and surveillance for the early detection of colorectal cancer and adenomatous polyps, 2008: a joint guideline from the American Cancer Society, the US Multi-Society Task Force on Colorectal Cancer, and the American College of Radiology'},
#     'series': '',
#     'date': '2008',
#     'pages': {'first-page': '1570', 'last-page': '1595'}},
#    'bib7': {'id': 'bib7',
#     'label': '7',
#     'authors': [{'given-name': 'D.K.', 'surname': 'Rex'},
#      {'given-name': 'D.A.', 'surname': 'Johnson'},
#      {'given-name': 'J.C.', 'surname': 'Anderson'}],
#     'title': {'maintitle': 'American College of Gastroenterology guidelines for colorectal cancer screening 2009 [corrected]'},
#     'series': '',
#     'date': '2009',
#     'pages': {'first-page': '739', 'last-page': '750'}},
#    'bib8': {'id': 'bib8',
#     'label': '8',
#     'authors': [{'given-name': 'A.', 'surname': 'Qaseem'},
#      {'given-name': 'T.D.', 'surname': 'Denberg'},
#      {'given-name': 'R.H.', 'surname': 'Hopkins', 'suffix': 'Jr'}],
#     'title': {'maintitle': 'Screening for colorectal cancer: a guidance statement from the American College of Physicians'},
#     'series': '',
#     'date': '2012',
#     'pages': {'first-page': '378', 'last-page': '386'}},
#    'bib9': {'id': 'bib9',
#     'label': '9',
#     'authors': [{'given-name': 'P.', 'surname': 'Schoenfeld'},
#      {'given-name': 'B.', 'surname': 'Cash'},
#      {'given-name': 'A.', 'surname': 'Flood'}],
#     'title': {'maintitle': 'Colonoscopic screening of average-risk women for colorectal neoplasia'},
#     'series': '',
#     'date': '2005',
#     'pages': {'first-page': '2061', 'last-page': '2068'}},
#    'bib10': {'id': 'bib10',
#     'label': '10',
#     'authors': [{'given-name': 'D.A.', 'surname': 'Lieberman'},
#      {'given-name': 'D.G.', 'surname': 'Weiss'},
#      {'given-name': 'J.H.', 'surname': 'Bond'}],
#     'title': {'maintitle': 'Use of colonoscopy to screen asymptomatic adults for colorectal cancer: Veterans Affairs Cooperative Study Group 380'},
#     'series': '',
#     'date': '2000',
#     'pages': {'first-page': '162', 'last-page': '168'}},
#    'bib11': {'id': 'bib11',
#     'label': '11',
#     'authors': [{'given-name': 'C.W.', 'surname': 'Ko'},
#      {'given-name': 'J.A.', 'surname': 'Dominitz'},
#      {'given-name': 'P.', 'surname': 'Green'}],
#     'title': {'maintitle': 'Accuracy of Medicare claims for identifying findings and procedures performed during colonoscopy'},
#     'series': '',
#     'date': '2011',
#     'pages': {'first-page': '447', 'last-page': '453'}},
#    'bib12': {'id': 'bib12',
#     'label': '12',
#     'authors': [{'given-name': 'D.', 'surname': 'Lieberman'}],
#     'title': {'maintitle': 'Pitfalls of using administrative data for research'},
#     'series': '',
#     'date': '2010',
#     'pages': {'first-page': '1506', 'last-page': '1508'}},
#    'bib13': {'id': 'bib13',
#     'label': '13',
#     'authors': [],
#     'title': {'maintitle': 'SNOMED CT. Volume 2012'},
#     'book': ''},
#    'bib14': {'id': 'bib14',
#     'label': '14',
#     'authors': [],
#     'title': {'maintitle': 'Unified Medical Language System. Volume 2012'},
#     'book': ''},
#    'bib15': {'id': 'bib15',
#     'label': '15',
#     'authors': [{'given-name': 'H.G.', 'surname': 'Kennedy'}],
#     'title': {'maintitle': 'Fatigue and fatigability'},
#     'series': '',
#     'date': '1987',
#     'pages': {'first-page': '1145'}},
#    'bib16': {'id': 'bib16',
#     'label': '16',
#     'authors': [{'given-name': 'H.G.', 'surname': 'Kennedy'}],
#     'title': {'maintitle': 'Fatigue and fatigability'},
#     'series': '',
#     'date': '1988',
#     'pages': {'first-page': '1', 'last-page': '5'}},
#    'bib17': {'id': 'bib17', 'label': '17', 'book': ''},
#    'bib18': {'id': 'bib18', 'label': '18', 'e-host': ''},
#    'bib19': {'id': 'bib19',
#     'label': '19',
#     'authors': [{'given-name': 'L.', 'surname': 'Ohno-Machado'}],
#     'title': {'maintitle': 'Realizing the full potential of electronic health records: the role of natural language processing'},
#     'series': '',
#     'date': '2011',
#     'pages': {'first-page': '539'}},
#    'bib20': {'id': 'bib20',
#     'label': '20',
#     'authors': [{'given-name': 'G.K.', 'surname': 'Savova'},
#      {'given-name': 'J.J.', 'surname': 'Masanz'},
#      {'given-name': 'P.V.', 'surname': 'Ogren'}],
#     'title': {'maintitle': 'Mayo clinical Text Analysis and Knowledge Extraction System (cTAKES): architecture, component evaluation and applications'},
#     'series': '',
#     'date': '2010',
#     'pages': {'first-page': '507', 'last-page': '513'}},
#    'bib21': {'id': 'bib21',
#     'label': '21',
#     'authors': [],
#     'title': {'maintitle': 'Unstructured Information Management Applications (UIMA)'},
#     'e-host': ''},
#    'bib22': {'id': 'bib22',
#     'label': '22',
#     'authors': [{'given-name': 'C.', 'surname': 'Lindberg'}],
#     'title': {'maintitle': 'The Unified Medical Language System (UMLS) of the National Library of Medicine'},
#     'series': '',
#     'date': '1990',
#     'pages': {'first-page': '40', 'last-page': '42'}},
#    'bib23': {'id': 'bib23',
#     'label': '23',
#     'authors': [{'given-name': 'V.', 'surname': 'Walden'}],
#     'title': {'maintitle': 'Defining the UMLS Metathesaurus'},
#     'series': '',
#     'date': '1996',
#     'pages': {'first-page': '38'}},
#    'bib24': {'id': 'bib24',
#     'label': '24',
#     'authors': [],
#     'title': {'maintitle': 'UMLS Metathesaurus Fact Sheet. Volume 2012'},
#     'book': ''},
#    'bib25': {'id': 'bib25',
#     'label': '25',
#     'authors': [{'given-name': 'C.J.', 'surname': 'Van Rijsbergen'}],
#     'title': {'maintitle': 'Information retrieval'},
#     'book': ''},
#    'bib26': {'id': 'bib26',
#     'label': '26',
#     'authors': [{'given-name': 'M.A.', 'surname': 'Al-Haddad'},
#      {'given-name': 'J.', 'surname': 'Friedlin'},
#      {'given-name': 'J.', 'surname': 'Kesterson'}],
#     'title': {'maintitle': 'Natural language processing for the development of a clinical registry: a validation study in intraductal papillary mucinous neoplasms'},
#     'series': '',
#     'date': '2010',
#     'pages': {'first-page': '688', 'last-page': '695'}},
#    'bib27': {'id': 'bib27',
#     'label': '27',
#     'authors': [{'given-name': 'J.C.', 'surname': 'Denny'},
#      {'given-name': 'J.F.', 'surname': 'Peterson'},
#      {'given-name': 'N.N.', 'surname': 'Choma'}],
#     'title': {'maintitle': 'Extracting timing and status descriptors for colonoscopy testing from electronic medical records'},
#     'series': '',
#     'date': '2010',
#     'pages': {'first-page': '383', 'last-page': '388'}},
#    'bib28': {'id': 'bib28',
#     'label': '28',
#     'authors': [{'given-name': 'H.', 'surname': 'Harkema'},
#      {'given-name': 'W.W.', 'surname': 'Chapman'},
#      {'given-name': 'M.', 'surname': 'Saul'}],
#     'title': {'maintitle': 'Developing a natural language processing application for measuring the quality of colonoscopy procedures'},
#     'series': '',
#     'date': '2011',
#     'pages': {'first-page': 'i150', 'last-page': 'i156'}},
#    'bib29': {'id': 'bib29',
#     'label': '29',
#     'authors': [{'given-name': 'J.C.', 'surname': 'Denny'},
#      {'given-name': 'N.N.', 'surname': 'Choma'},
#      {'given-name': 'J.F.', 'surname': 'Peterson'}],
#     'title': {'maintitle': 'Natural language processing improves identification of colorectal cancer testing in the electronic medical record'},
#     'series': '',
#     'date': '2012',
#     'pages': {'first-page': '188', 'last-page': '197'}},
#    'bib30': {'id': 'bib30',
#     'label': '30',
#     'authors': [{'given-name': 'A.', 'surname': 'Mehrotra'},
#      {'given-name': 'E.S.', 'surname': 'Dellon'},
#      {'given-name': 'R.E.', 'surname': 'Schoen'}],
#     'title': {'maintitle': 'Applying a natural language processing tool to electronic health records to assess performance on colonoscopy quality measures'},
#     'series': '',
#     'date': '2012',
#     'pages': {'first-page': '1233', 'last-page': '1239'}},
#    'bib31': {'id': 'bib31',
#     'label': '31',
#     'authors': [{'given-name': 'S.', 'surname': 'Rea'},
#      {'given-name': 'J.', 'surname': 'Pathak'},
#      {'given-name': 'G.', 'surname': 'Savova'}],
#     'title': {'maintitle': 'Building a robust, scalable and standards-driven infrastructure for secondary use of EHR data: the SHARPn project'},
#     'series': '',
#     'date': '2012',
#     'pages': {'first-page': '763', 'last-page': '771'}},
#    'bib32': {'id': 'bib32',
#     'label': '32',
#     'authors': [{'given-name': 'K.', 'surname': 'Holzer'},
#      {'given-name': 'W.', 'surname': 'Gall'}],
#     'title': {'maintitle': 'Utilizing IHE-based electronic health record systems for secondary use'},
#     'series': '',
#     'date': '2011',
#     'pages': {'first-page': '319', 'last-page': '325'}},
#    'bib33': {'id': 'bib33',
#     'label': '33',
#     'authors': [{'given-name': 'A.', 'surname': 'Jain'},
#      {'given-name': 'S.', 'surname': 'Hayden'}],
#     'title': {'maintitle': 'Using electronic health records to collect patient-specific performance measures and outcomes'},
#     'series': '',
#     'date': '2008',
#     'pages': {'first-page': '1242', 'last-page': '1243'}}}}}

# %%
bib2para = doc.metadatas['bib2para']
bib2para.meta_dict
# Out:
# {'fig1': ['/root/sec_0/para_4'],
#  'bib20': ['/root/sec_0/para_6'],
#  'bib21': ['/root/sec_0/para_6'],
#  'bib22': ['/root/sec_0/para_6'],
#  'bib23': ['/root/sec_0/para_6'],
#  'bib24': ['/root/sec_0/para_6'],
#  'bib25': ['/root/sec_0/para_12'],
#  'tbl1': ['/root/sec_1/para_2'],
#  'tbl2': ['/root/sec_1/para_3',
#   '/root/sec_1/para_4',
#   '/root/sec_1/para_5',
#   '/root/sec_1/para_6'],
#  'fig2': ['/root/sec_1/para_8'],
#  'bib26': ['/root/sec_2/para_1'],
#  'bib27': ['/root/sec_2/para_1'],
#  'bib28': ['/root/sec_2/para_1',
#   '/root/sec_2/para_1',
#   '/root/sec_2/para_2',
#   '/root/sec_2/para_8'],
#  'bib29': ['/root/sec_2/para_1'],
#  'bib30': ['/root/sec_2/para_1', '/root/sec_2/para_3', '/root/sec_2/para_8'],
#  'bib31': ['/root/sec_2/para_4'],
#  'bib32': ['/root/sec_2/para_4'],
#  'bib33': ['/root/sec_2/para_4'],
#  'bib16': ['/root/sec_2/para_7']}

# %% [markdown]
# ## 从 paragraph id 反查段落

# %%
paraid_map = doc.get_paragraphs()
paraid_map
# Out:
# {'/root/sec_0/para_0': <data_platform.document.Paragraph at 0x1d23648d860>,
#  '/root/sec_0/para_1': <data_platform.document.Paragraph at 0x1d23648d8d0>,
#  '/root/sec_0/para_2': <data_platform.document.Paragraph at 0x1d23648d940>,
#  '/root/sec_0/para_3': <data_platform.document.Paragraph at 0x1d23648d9b0>,
#  '/root/sec_0/para_4': <data_platform.document.Paragraph at 0x1d23648da20>,
#  '/root/sec_0/para_5': <data_platform.document.Paragraph at 0x1d23648db70>,
#  '/root/sec_0/para_6': <data_platform.document.Paragraph at 0x1d23648dbe0>,
#  '/root/sec_0/para_7': <data_platform.document.Paragraph at 0x1d23648de10>,
#  '/root/sec_0/para_8': <data_platform.document.Paragraph at 0x1d23648de80>,
#  '/root/sec_0/para_9': <data_platform.document.Paragraph at 0x1d23648def0>,
#  '/root/sec_0/para_10': <data_platform.document.Paragraph at 0x1d23648df60>,
#  '/root/sec_0/para_11': <data_platform.document.Paragraph at 0x1d23648dfd0>,
#  '/root/sec_0/para_12': <data_platform.document.Paragraph at 0x1d236495080>,
#  '/root/sec_0/para_13': <data_platform.document.Paragraph at 0x1d236495160>,
#  '/root/sec_1/para_0': <data_platform.document.Paragraph at 0x1d236495208>,
#  '/root/sec_1/para_1': <data_platform.document.Paragraph at 0x1d236495278>,
#  '/root/sec_1/para_2': <data_platform.document.Paragraph at 0x1d2364952e8>,
#  '/root/sec_1/para_3': <data_platform.document.Paragraph at 0x1d236495438>,
#  '/root/sec_1/para_4': <data_platform.document.Paragraph at 0x1d236495588>,
#  '/root/sec_1/para_5': <data_platform.document.Paragraph at 0x1d236495668>,
#  '/root/sec_1/para_6': <data_platform.document.Paragraph at 0x1d236495748>,
#  '/root/sec_1/para_7': <data_platform.document.Paragraph at 0x1d236495828>,
#  '/root/sec_1/para_8': <data_platform.document.Paragraph at 0x1d236495898>,
#  '/root/sec_2/para_0': <data_platform.document.Paragraph at 0x1d236495a20>,
#  '/root/sec_2/para_1': <data_platform.document.Paragraph at 0x1d236495a90>,
#  '/root/sec_2/para_2': <data_platform.document.Paragraph at 0x1d236495be0>,
#  '/root/sec_2/para_3': <data_platform.document.Paragraph at 0x1d236495cc0>,
#  '/root/sec_2/para_4': <data_platform.document.Paragraph at 0x1d236495e10>,
#  '/root/sec_2/para_5': <data_platform.document.Paragraph at 0x1d236495ef0>,
#  '/root/sec_2/para_6': <data_platform.document.Paragraph at 0x1d236495f60>,
#  '/root/sec_2/para_7': <data_platform.document.Paragraph at 0x1d236495fd0>,
#  '/root/sec_2/para_8': <data_platform.document.Paragraph at 0x1d23649f160>,
#  '/root/sec_2/para_9': <data_platform.document.Paragraph at 0x1d23649f2b0>,
#  '/root/sec_2/para_10': <data_platform.document.Paragraph at 0x1d23649f320>,
#  '/root/sec_2/para_11': <data_platform.document.Paragraph at 0x1d23649f390>,
#  '/root/sec_3/para_0': <data_platform.document.Paragraph at 0x1d23649f438>,
#  '/root/sec_3/para_1': <data_platform.document.Paragraph at 0x1d23649f4a8>}

# %% [markdown]
# ## 核心元数据

# %%
coredata = doc.metadatas['coredata']
coredata.meta_dict
# Out:
# {'url': 'https://api.elsevier.com/content/article/pii/S1542356513000104',
#  'identifier': 'doi:10.1016/j.cgh.2012.11.035',
#  'eid': '1-s2.0-S1542356513000104',
#  'doi': '10.1016/j.cgh.2012.11.035',
#  'pii': 'S1542-3565(13)00010-4',
#  'title': 'Natural Language Processing Accurately Categorizes Findings From Colonoscopy and Pathology Reports',
#  'publicationName': 'Clinical Gastroenterology and Hepatology',
#  'aggregationType': 'Journal',
#  'pubType': 'Original article\n               \n                  Alimentary tract',
#  'issn': '15423565',
#  'volume': '11',
#  'issueIdentifier': '6',
#  'startingPage': '689',
#  'endingPage': '694',
#  'pageRange': '689-694',
#  'number': '6',
#  'format': 'text/xml',
#  'coverDate': '2013-06-30',
#  'coverDisplayDate': 'June 2013',
#  'copyright': 'Copyright © 2013 AGA Institute. Published by Elsevier Ltd. All rights reserved.',
#  'publisher': 'AGA Institute. Published by Elsevier Ltd.',
#  'creator': 'Imperiale, Thomas F.',
#  'description': 'Background & Aims\n                  Little is known about the ability of natural language processing (NLP) to extract meaningful information from free-text gastroenterology reports for secondary use.\n               \n               \n                  Methods\n                  We randomly selected 500 linked colonoscopy and pathology reports from 10,798 nonsurveillance colonoscopies to train and test the NLP system. By using annotation by gastroenterologists as the reference standard, we assessed the accuracy of an open-source NLP engine that processed and extracted clinically relevant concepts. The primary outcome was the highest level of pathology. Secondary outcomes were location of the most advanced lesion, largest size of an adenoma removed, and number of adenomas removed.\n               \n               \n                  Results\n                  The NLP system identified the highest level of pathology with 98% accuracy, compared with triplicate annotation by gastroenterologists (the standard). Accuracy values for location, size, and number were 97%, 96%, and 84%, respectively.\n               \n               \n                  Conclusions\n                  The NLP can extract specific meaningful concepts with 98% accuracy. It might be developed as a method to further quantify specific quality metrics.',
#  'openaccess': '0',
#  'openaccessArticle': 'false',
#  'openaccessType': '',
#  'openArchiveArticle': 'false',
#  'openaccessSponsorName': '',
#  'openaccessSponsorType': '',
#  'openaccessUserLicense': '',
#  'subject': 'Medical Informatics',
#  'link': ''}
